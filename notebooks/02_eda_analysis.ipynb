# %% [markdown]
# # 02 — Exploratory Data Analysis
#
# Answer the key business questions defined in the project plan.

# %%
import pandas as pd
from sqlalchemy import create_engine
import sys; sys.path.append('../src')
from eda_utils import revenue_by_category, monthly_orders

engine = create_engine('sqlite:///../data/ecommerce.db')
df = pd.read_sql('SELECT * FROM master', engine)
df.shape
