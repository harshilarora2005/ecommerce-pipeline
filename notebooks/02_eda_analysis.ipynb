# %% [markdown]
# # 02 — Exploratory Data Analysis
#
# Answer the core business questions: what sells, where, when, and how well?

# %%
import os
print(os.path.abspath('../data/ecommerce.db'))
# Out:
# /Users/harshilarora/Documents/ecommerce-pipeline/data/ecommerce.db

# %%
import sys, pandas as pd
from sqlalchemy import create_engine
sys.path.append('../src')
from eda_utils import (chart_revenue_by_category, chart_monthly_revenue, chart_state_revenue,
                       chart_review_distribution, chart_delivery_vs_review, chart_payment_breakdown)

engine = create_engine('sqlite:///../data/ecommerce.db')
df = pd.read_sql('SELECT * FROM master', engine, parse_dates=['order_purchase_timestamp'])
print('Rows:', len(df), '| Orders:', df.order_id.nunique(), '| Customers:', df.customer_unique_id.nunique())
df.head()
# Out:
# Rows: 112650 | Orders: 98666 | Customers: 95420
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  \
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# ...

# %% [markdown]
# ## Q1. Which categories drive revenue?

# %%
chart_revenue_by_category(df, 15).show()

# %% [markdown]
# ## Q2. Revenue trend over time

# %%
chart_monthly_revenue(df).show()

# %% [markdown]
# ## Q3. Geographic distribution

# %%
chart_state_revenue(df).show()

# %% [markdown]
# ## Q4. Review score distribution + delivery impact

# %%
chart_review_distribution(df).show()
chart_delivery_vs_review(df).show()

# %% [markdown]
# ## Q5. Payment behaviour

# %%
chart_payment_breakdown(df).show()

# %% [markdown]
# ## Q6. Pareto check — revenue concentration by state

# %%
state = df.groupby('customer_state')['revenue'].sum().sort_values(ascending=False)
share = (state.cumsum() / state.sum() * 100).round(1)
share.head(10)
# Out:
# customer_state
# SP    37.4
# RJ    50.8
# MG    62.5
# RS    68.1
# PR    73.2
# BA    77.0
# SC    80.9
# DF    83.1
# GO    85.3
# ES    87.4
# Name: revenue, dtype: float64
